# %%
import torch
import argparse
import os

def count_parameters(checkpoint_path):
    if not os.path.exists(checkpoint_path):
        print(f"Error: Checkpoint file not found at {checkpoint_path}")
        return

    try:
        print(f"Loading checkpoint from: {checkpoint_path}")
        checkpoint = torch.load(checkpoint_path, map_location='cpu')
        
        if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
            print("Found 'model_state_dict' in checkpoint dictionary.")
            state_dict = checkpoint['model_state_dict']
        else:
            print("Assuming checkpoint is the state dictionary itself.")
            state_dict = checkpoint
            
        total_params = 0
        trainable_params = 0 # This estimate is less accurate if we don't have the model class instantiated, but usually all in state_dict are parameters.
        
        print("-" * 50)
        print(f"{'Layer':<60} {'Parameters':>15}")
        print("-" * 50)
        
        for key, value in state_dict.items():
            params = value.numel()
            total_params += params
            print(f"{key:<60} {params:>15,}")
            
        print("-" * 50)
        print(f"Total parameters: {total_params:,}")
        print("-" * 50)
        
    except Exception as e:
        print(f"Error loading checkpoint: {e}")

# %%
checkpoint_path = "logs/20260220-145403/checkpoints/checkpoint_epoch_500.pt"
count_parameters(checkpoint_path)
# Out:
# Loading checkpoint from: logs/20260220-145403/checkpoints/checkpoint_epoch_500.pt
# Found 'model_state_dict' in checkpoint dictionary.
# --------------------------------------------------
# Layer                                                             Parameters
# --------------------------------------------------
# pointnet_encoder.point_net.0.weight                                    3,072
# pointnet_encoder.point_net.1.weight                                      512
# pointnet_encoder.point_net.1.bias                                        512
# pointnet_encoder.point_net.1.running_mean                                512
# pointnet_encoder.point_net.1.running_var                                 512
# pointnet_encoder.point_net.1.num_batches_tracked                           1
# pointnet_encoder.point_net.3.weight                                  524,288
# pointnet_encoder.point_net.4.weight                                    1,024
# pointnet_encoder.point_net.4.bias                                      1,024
# pointnet_encoder.point_net.4.running_mean                              1,024
# pointnet_encoder.point_net.4.running_var                               1,024
# pointnet_encoder.point_net.4.num_batches_tracked                           1
# pointnet_encoder.point_net.6.weight                                2,097,152
# pointnet_encoder.point_net.7.weight                                    2,048
# pointnet_encoder.point_net.7.bias                                      2,048
# pointnet_encoder.point_net.7.running_mean                              2,048
# pointnet_encoder.point_net.7.running_var                               2,048
# pointnet_encoder.point_net.7.num_batches_tracked                           1
# pointnet_encoder.point_net.9.weight                                2,097,152
# pointnet_encoder.point_net.10.weight                                   1,024
# pointnet_encoder.point_net.10.bias                                     1,024
# pointnet_encoder.point_net.10.running_mean                             1,024
# pointnet_encoder.point_net.10.running_var                              1,024
# pointnet_encoder.point_net.10.num_batches_tracked                          1
# pointnet_encoder.property_encoder.type_embedding.weight                1,280
# pointnet_encoder.property_encoder.prop_mlp.0.weight                    2,880
# pointnet_encoder.property_encoder.prop_mlp.1.weight                      960
# pointnet_encoder.property_encoder.prop_mlp.1.bias                        960
# pointnet_encoder.property_encoder.prop_mlp.1.running_mean                960
# pointnet_encoder.property_encoder.prop_mlp.1.running_var                 960
# pointnet_encoder.property_encoder.prop_mlp.1.num_batches_tracked               1
# pointnet_encoder.property_encoder.final_proj.0.weight              1,048,576
# pointnet_encoder.property_encoder.final_proj.1.weight                  1,024
# pointnet_encoder.property_encoder.final_proj.1.bias                    1,024
# pointnet_encoder.property_encoder.final_proj.1.running_mean            1,024
# pointnet_encoder.property_encoder.final_proj.1.running_var             1,024
# pointnet_encoder.property_encoder.final_proj.1.num_batches_tracked               1
# pointnet_encoder.fusion_mlp.0.weight                               2,097,152
# pointnet_encoder.fusion_mlp.1.weight                                   1,024
# pointnet_encoder.fusion_mlp.1.bias                                     1,024
# pointnet_encoder.fusion_mlp.1.running_mean                             1,024
# pointnet_encoder.fusion_mlp.1.running_var                              1,024
# pointnet_encoder.fusion_mlp.1.num_batches_tracked                          1
# pointnet_encoder.fusion_mlp.3.weight                               1,048,576
# pointnet_encoder.fusion_mlp.4.weight                                   1,024
# pointnet_encoder.fusion_mlp.4.bias                                     1,024
# pointnet_encoder.fusion_mlp.4.running_mean                             1,024
# pointnet_encoder.fusion_mlp.4.running_var                              1,024
# pointnet_encoder.fusion_mlp.4.num_batches_tracked                          1
# state_manager.tokens                                                  65,536
# state_manager.grid_positions                                              81
# scene_transformer.layers.0.norm_state1.weight                          1,024
# scene_transformer.layers.0.norm_state1.bias                            1,024
# scene_transformer.layers.0.norm_obj1.weight                            1,024
# scene_transformer.layers.0.norm_obj1.bias                              1,024
# scene_transformer.layers.0.norm_state2.weight                          1,024
# scene_transformer.layers.0.norm_state2.bias                            1,024
# scene_transformer.layers.0.norm_obj2.weight                            1,024
# scene_transformer.layers.0.norm_obj2.bias                              1,024
# scene_transformer.layers.0.norm_state_self.weight                      1,024
# scene_transformer.layers.0.norm_state_self.bias                        1,024
# scene_transformer.layers.0.cross_attn_state_to_obj.in_proj_weight       3,145,728
# scene_transformer.layers.0.cross_attn_state_to_obj.in_proj_bias           3,072
# scene_transformer.layers.0.cross_attn_state_to_obj.out_proj.weight       1,048,576
# scene_transformer.layers.0.cross_attn_state_to_obj.out_proj.bias           1,024
# scene_transformer.layers.0.cross_attn_obj_to_state.in_proj_weight       3,145,728
# scene_transformer.layers.0.cross_attn_obj_to_state.in_proj_bias           3,072
# scene_transformer.layers.0.cross_attn_obj_to_state.out_proj.weight       1,048,576
# scene_transformer.layers.0.cross_attn_obj_to_state.out_proj.bias           1,024
# scene_transformer.layers.0.self_attn_state.in_proj_weight          3,145,728
# scene_transformer.layers.0.self_attn_state.in_proj_bias                3,072
# scene_transformer.layers.0.self_attn_state.out_proj.weight         1,048,576
# scene_transformer.layers.0.self_attn_state.out_proj.bias               1,024
# scene_transformer.layers.0.ffn_state.0.weight                      2,097,152
# scene_transformer.layers.0.ffn_state.0.bias                            2,048
# scene_transformer.layers.0.ffn_state.3.weight                      2,097,152
# scene_transformer.layers.0.ffn_state.3.bias                            1,024
# scene_transformer.layers.0.ffn_obj.0.weight                        2,097,152
# scene_transformer.layers.0.ffn_obj.0.bias                              2,048
# scene_transformer.layers.0.ffn_obj.3.weight                        2,097,152
# scene_transformer.layers.0.ffn_obj.3.bias                              1,024
# scene_transformer.layers.1.norm_state1.weight                          1,024
# scene_transformer.layers.1.norm_state1.bias                            1,024
# scene_transformer.layers.1.norm_obj1.weight                            1,024
# scene_transformer.layers.1.norm_obj1.bias                              1,024
# scene_transformer.layers.1.norm_state2.weight                          1,024
# scene_transformer.layers.1.norm_state2.bias                            1,024
# scene_transformer.layers.1.norm_obj2.weight                            1,024
# scene_transformer.layers.1.norm_obj2.bias                              1,024
# scene_transformer.layers.1.norm_state_self.weight                      1,024
# scene_transformer.layers.1.norm_state_self.bias                        1,024
# scene_transformer.layers.1.cross_attn_state_to_obj.in_proj_weight       3,145,728
# scene_transformer.layers.1.cross_attn_state_to_obj.in_proj_bias           3,072
# scene_transformer.layers.1.cross_attn_state_to_obj.out_proj.weight       1,048,576
# scene_transformer.layers.1.cross_attn_state_to_obj.out_proj.bias           1,024
# scene_transformer.layers.1.cross_attn_obj_to_state.in_proj_weight       3,145,728
# scene_transformer.layers.1.cross_attn_obj_to_state.in_proj_bias           3,072
# scene_transformer.layers.1.cross_attn_obj_to_state.out_proj.weight       1,048,576
# scene_transformer.layers.1.cross_attn_obj_to_state.out_proj.bias           1,024
# scene_transformer.layers.1.self_attn_state.in_proj_weight          3,145,728
# scene_transformer.layers.1.self_attn_state.in_proj_bias                3,072
# scene_transformer.layers.1.self_attn_state.out_proj.weight         1,048,576
# scene_transformer.layers.1.self_attn_state.out_proj.bias               1,024
# scene_transformer.layers.1.ffn_state.0.weight                      2,097,152
# scene_transformer.layers.1.ffn_state.0.bias                            2,048
# scene_transformer.layers.1.ffn_state.3.weight                      2,097,152
# scene_transformer.layers.1.ffn_state.3.bias                            1,024
# scene_transformer.layers.1.ffn_obj.0.weight                        2,097,152
# scene_transformer.layers.1.ffn_obj.0.bias                              2,048
# scene_transformer.layers.1.ffn_obj.3.weight                        2,097,152
# scene_transformer.layers.1.ffn_obj.3.bias                              1,024
# scene_transformer.layers.2.norm_state1.weight                          1,024
# scene_transformer.layers.2.norm_state1.bias                            1,024
# scene_transformer.layers.2.norm_obj1.weight                            1,024
# scene_transformer.layers.2.norm_obj1.bias                              1,024
# scene_transformer.layers.2.norm_state2.weight                          1,024
# scene_transformer.layers.2.norm_state2.bias                            1,024
# scene_transformer.layers.2.norm_obj2.weight                            1,024
# scene_transformer.layers.2.norm_obj2.bias                              1,024
# scene_transformer.layers.2.norm_state_self.weight                      1,024
# scene_transformer.layers.2.norm_state_self.bias                        1,024
# scene_transformer.layers.2.cross_attn_state_to_obj.in_proj_weight       3,145,728
# scene_transformer.layers.2.cross_attn_state_to_obj.in_proj_bias           3,072
# scene_transformer.layers.2.cross_attn_state_to_obj.out_proj.weight       1,048,576
# scene_transformer.layers.2.cross_attn_state_to_obj.out_proj.bias           1,024
# scene_transformer.layers.2.cross_attn_obj_to_state.in_proj_weight       3,145,728
# scene_transformer.layers.2.cross_attn_obj_to_state.in_proj_bias           3,072
# scene_transformer.layers.2.cross_attn_obj_to_state.out_proj.weight       1,048,576
# scene_transformer.layers.2.cross_attn_obj_to_state.out_proj.bias           1,024
# scene_transformer.layers.2.self_attn_state.in_proj_weight          3,145,728
# scene_transformer.layers.2.self_attn_state.in_proj_bias                3,072
# scene_transformer.layers.2.self_attn_state.out_proj.weight         1,048,576
# scene_transformer.layers.2.self_attn_state.out_proj.bias               1,024
# scene_transformer.layers.2.ffn_state.0.weight                      2,097,152
# scene_transformer.layers.2.ffn_state.0.bias                            2,048
# scene_transformer.layers.2.ffn_state.3.weight                      2,097,152
# scene_transformer.layers.2.ffn_state.3.bias                            1,024
# scene_transformer.layers.2.ffn_obj.0.weight                        2,097,152
# scene_transformer.layers.2.ffn_obj.0.bias                              2,048
# scene_transformer.layers.2.ffn_obj.3.weight                        2,097,152
# scene_transformer.layers.2.ffn_obj.3.bias                              1,024
# scene_transformer.layers.3.norm_state1.weight                          1,024
# scene_transformer.layers.3.norm_state1.bias                            1,024
# scene_transformer.layers.3.norm_obj1.weight                            1,024
# scene_transformer.layers.3.norm_obj1.bias                              1,024
# scene_transformer.layers.3.norm_state2.weight                          1,024
# scene_transformer.layers.3.norm_state2.bias                            1,024
# scene_transformer.layers.3.norm_obj2.weight                            1,024
# scene_transformer.layers.3.norm_obj2.bias                              1,024
# scene_transformer.layers.3.norm_state_self.weight                      1,024
# scene_transformer.layers.3.norm_state_self.bias                        1,024
# scene_transformer.layers.3.cross_attn_state_to_obj.in_proj_weight       3,145,728
# scene_transformer.layers.3.cross_attn_state_to_obj.in_proj_bias           3,072
# scene_transformer.layers.3.cross_attn_state_to_obj.out_proj.weight       1,048,576
# scene_transformer.layers.3.cross_attn_state_to_obj.out_proj.bias           1,024
# scene_transformer.layers.3.cross_attn_obj_to_state.in_proj_weight       3,145,728
# scene_transformer.layers.3.cross_attn_obj_to_state.in_proj_bias           3,072
# scene_transformer.layers.3.cross_attn_obj_to_state.out_proj.weight       1,048,576
# scene_transformer.layers.3.cross_attn_obj_to_state.out_proj.bias           1,024
# scene_transformer.layers.3.self_attn_state.in_proj_weight          3,145,728
# scene_transformer.layers.3.self_attn_state.in_proj_bias                3,072
# scene_transformer.layers.3.self_attn_state.out_proj.weight         1,048,576
# scene_transformer.layers.3.self_attn_state.out_proj.bias               1,024
# scene_transformer.layers.3.ffn_state.0.weight                      2,097,152
# scene_transformer.layers.3.ffn_state.0.bias                            2,048
# scene_transformer.layers.3.ffn_state.3.weight                      2,097,152
# scene_transformer.layers.3.ffn_state.3.bias                            1,024
# scene_transformer.layers.3.ffn_obj.0.weight                        2,097,152
# scene_transformer.layers.3.ffn_obj.0.bias                              2,048
# scene_transformer.layers.3.ffn_obj.3.weight                        2,097,152
# scene_transformer.layers.3.ffn_obj.3.bias                              1,024
# ray_encoder.ray_map_patch_token                                        1,024
# ray_encoder.patch_grid_proj.weight                                    34,816
# ray_encoder.patch_grid_proj.bias                                       1,024
# ray_encoder.pe_token_proj.weight                                     156,672
# ray_encoder.pe_token_proj.bias                                         1,024
# ray_encoder.token_pos_pe_norm.weight                                   1,024
# ray_encoder.token_pos_pe_norm.bias                                     1,024
# ray_encoder.ray_map_encoder.weight                                 3,342,336
# ray_encoder.ray_map_encoder.bias                                       1,024
# ray_encoder.ray_map_encoder_norm.weight                                1,024
# ray_encoder.ray_map_encoder_norm.bias                                  1,024
# predictor.layer_weights                                                    3
# predictor.transformer.layers.0.self_attn.in_proj_weight            3,145,728
# predictor.transformer.layers.0.self_attn.in_proj_bias                  3,072
# predictor.transformer.layers.0.self_attn.out_proj.weight           1,048,576
# predictor.transformer.layers.0.self_attn.out_proj.bias                 1,024
# predictor.transformer.layers.0.multihead_attn.in_proj_weight       3,145,728
# predictor.transformer.layers.0.multihead_attn.in_proj_bias             3,072
# predictor.transformer.layers.0.multihead_attn.out_proj.weight       1,048,576
# predictor.transformer.layers.0.multihead_attn.out_proj.bias            1,024
# predictor.transformer.layers.0.linear1.weight                      4,194,304
# predictor.transformer.layers.0.linear1.bias                            4,096
# predictor.transformer.layers.0.linear2.weight                      4,194,304
# predictor.transformer.layers.0.linear2.bias                            1,024
# predictor.transformer.layers.0.norm1.weight                            1,024
# predictor.transformer.layers.0.norm1.bias                              1,024
# predictor.transformer.layers.0.norm2.weight                            1,024
# predictor.transformer.layers.0.norm2.bias                              1,024
# predictor.transformer.layers.0.norm3.weight                            1,024
# predictor.transformer.layers.0.norm3.bias                              1,024
# predictor.transformer.layers.1.self_attn.in_proj_weight            3,145,728
# predictor.transformer.layers.1.self_attn.in_proj_bias                  3,072
# predictor.transformer.layers.1.self_attn.out_proj.weight           1,048,576
# predictor.transformer.layers.1.self_attn.out_proj.bias                 1,024
# predictor.transformer.layers.1.multihead_attn.in_proj_weight       3,145,728
# predictor.transformer.layers.1.multihead_attn.in_proj_bias             3,072
# predictor.transformer.layers.1.multihead_attn.out_proj.weight       1,048,576
# predictor.transformer.layers.1.multihead_attn.out_proj.bias            1,024
# predictor.transformer.layers.1.linear1.weight                      4,194,304
# predictor.transformer.layers.1.linear1.bias                            4,096
# predictor.transformer.layers.1.linear2.weight                      4,194,304
# predictor.transformer.layers.1.linear2.bias                            1,024
# predictor.transformer.layers.1.norm1.weight                            1,024
# predictor.transformer.layers.1.norm1.bias                              1,024
# predictor.transformer.layers.1.norm2.weight                            1,024
# predictor.transformer.layers.1.norm2.bias                              1,024
# predictor.transformer.layers.1.norm3.weight                            1,024
# predictor.transformer.layers.1.norm3.bias                              1,024
# predictor.transformer.layers.2.self_attn.in_proj_weight            3,145,728
# predictor.transformer.layers.2.self_attn.in_proj_bias                  3,072
# predictor.transformer.layers.2.self_attn.out_proj.weight           1,048,576
# predictor.transformer.layers.2.self_attn.out_proj.bias                 1,024
# predictor.transformer.layers.2.multihead_attn.in_proj_weight       3,145,728
# predictor.transformer.layers.2.multihead_attn.in_proj_bias             3,072
# predictor.transformer.layers.2.multihead_attn.out_proj.weight       1,048,576
# predictor.transformer.layers.2.multihead_attn.out_proj.bias            1,024
# predictor.transformer.layers.2.linear1.weight                      4,194,304
# predictor.transformer.layers.2.linear1.bias                            4,096
# predictor.transformer.layers.2.linear2.weight                      4,194,304
# predictor.transformer.layers.2.linear2.bias                            1,024
# predictor.transformer.layers.2.norm1.weight                            1,024
# predictor.transformer.layers.2.norm1.bias                              1,024
# predictor.transformer.layers.2.norm2.weight                            1,024
# predictor.transformer.layers.2.norm2.bias                              1,024
# predictor.transformer.layers.2.norm3.weight                            1,024
# predictor.transformer.layers.2.norm3.bias                              1,024
# predictor.transformer.layers.3.self_attn.in_proj_weight            3,145,728
# predictor.transformer.layers.3.self_attn.in_proj_bias                  3,072
# predictor.transformer.layers.3.self_attn.out_proj.weight           1,048,576
# predictor.transformer.layers.3.self_attn.out_proj.bias                 1,024
# predictor.transformer.layers.3.multihead_attn.in_proj_weight       3,145,728
# predictor.transformer.layers.3.multihead_attn.in_proj_bias             3,072
# predictor.transformer.layers.3.multihead_attn.out_proj.weight       1,048,576
# predictor.transformer.layers.3.multihead_attn.out_proj.bias            1,024
# predictor.transformer.layers.3.linear1.weight                      4,194,304
# predictor.transformer.layers.3.linear1.bias                            4,096
# predictor.transformer.layers.3.linear2.weight                      4,194,304
# predictor.transformer.layers.3.linear2.bias                            1,024
# predictor.transformer.layers.3.norm1.weight                            1,024
# predictor.transformer.layers.3.norm1.bias                              1,024
# predictor.transformer.layers.3.norm2.weight                            1,024
# predictor.transformer.layers.3.norm2.bias                              1,024
# predictor.transformer.layers.3.norm3.weight                            1,024
# predictor.transformer.layers.3.norm3.bias                              1,024
# predictor.transformer.layers.4.self_attn.in_proj_weight            3,145,728
# predictor.transformer.layers.4.self_attn.in_proj_bias                  3,072
# predictor.transformer.layers.4.self_attn.out_proj.weight           1,048,576
# predictor.transformer.layers.4.self_attn.out_proj.bias                 1,024
# predictor.transformer.layers.4.multihead_attn.in_proj_weight       3,145,728
# predictor.transformer.layers.4.multihead_attn.in_proj_bias             3,072
# predictor.transformer.layers.4.multihead_attn.out_proj.weight       1,048,576
# predictor.transformer.layers.4.multihead_attn.out_proj.bias            1,024
# predictor.transformer.layers.4.linear1.weight                      4,194,304
# predictor.transformer.layers.4.linear1.bias                            4,096
# predictor.transformer.layers.4.linear2.weight                      4,194,304
# predictor.transformer.layers.4.linear2.bias                            1,024
# predictor.transformer.layers.4.norm1.weight                            1,024
# predictor.transformer.layers.4.norm1.bias                              1,024
# predictor.transformer.layers.4.norm2.weight                            1,024
# predictor.transformer.layers.4.norm2.bias                              1,024
# predictor.transformer.layers.4.norm3.weight                            1,024
# predictor.transformer.layers.4.norm3.bias                              1,024
# predictor.transformer.layers.5.self_attn.in_proj_weight            3,145,728
# predictor.transformer.layers.5.self_attn.in_proj_bias                  3,072
# predictor.transformer.layers.5.self_attn.out_proj.weight           1,048,576
# predictor.transformer.layers.5.self_attn.out_proj.bias                 1,024
# predictor.transformer.layers.5.multihead_attn.in_proj_weight       3,145,728
# predictor.transformer.layers.5.multihead_attn.in_proj_bias             3,072
# predictor.transformer.layers.5.multihead_attn.out_proj.weight       1,048,576
# predictor.transformer.layers.5.multihead_attn.out_proj.bias            1,024
# predictor.transformer.layers.5.linear1.weight                      4,194,304
# predictor.transformer.layers.5.linear1.bias                            4,096
# predictor.transformer.layers.5.linear2.weight                      4,194,304
# predictor.transformer.layers.5.linear2.bias                            1,024
# predictor.transformer.layers.5.norm1.weight                            1,024
# predictor.transformer.layers.5.norm1.bias                              1,024
# predictor.transformer.layers.5.norm2.weight                            1,024
# predictor.transformer.layers.5.norm2.bias                              1,024
# predictor.transformer.layers.5.norm3.weight                            1,024
# predictor.transformer.layers.5.norm3.bias                              1,024
# predictor.out_proj.0.weight                                        1,048,576
# predictor.out_proj.0.bias                                              1,024
# predictor.out_proj.2.weight                                        1,048,576
# predictor.out_proj.2.bias                                              1,024
# predictor.out_proj.4.weight                                        1,048,576
# predictor.out_proj.4.bias                                              1,024
# predictor.out_proj.6.weight                                          196,608
# predictor.out_proj.6.bias                                                192
# --------------------------------------------------
# Total parameters: 200,688,732
# --------------------------------------------------
